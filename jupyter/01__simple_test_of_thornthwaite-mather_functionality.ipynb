# %% [markdown]
# # Test 1: Basic SWB2 options and Thornthwaite-Mather water budget
#
# This test combines the most commonly used SWB2 program options and completes a model run using tabular precipitation and air tempterature inputs. The output is compared to the same calculations made using a simple Python version of the same algorithms, _as well as a version of the algorithms that references the original Thornthwaite-Mather soil-moisture-retention tables._ This test provides checks on the following functionality:
#
# 1. Partitioning of gross precipitation into 'rainfall' and 'snowfall' fractions;
# 2. Temperature index-based snowmelt;
# 3. Thornthwaite-Mather soil-moisture-retention algorithm implementation as compared to tabular values;
# 4. Hargreaves-Samani calculation for reference evapotranspiration.
#
# For this test, a curve number of '0' is used in the SWB run, essentially ensuring that there is never any runoff calculated in SWB. This is done to make the initial comparison to the Thornthwaite-Mather soil-moisture-retention tables easier to understand. The only active sources of water are rainfall and snowmelt; the sinks are actual evapotranspiration and net infiltration.
#
# The first half of this notebook may be skipped unless one is interested in the details of how the various model runs are set up. Basically, a simple SWB2 model is executed, followed by a set of Python implementations of SWB2. The results are compared in the last half of this notebook.

# %% [markdown]
# ## Test setup

# %%
# high-level imports
import pandas as pd
import matplotlib.pyplot as plt
import pathlib as pl
import sys
import subprocess

# %% [markdown]
# #### Define paths to swb2 executable and working/input data directories

# %%
# define working directories for use in making a forward run of SWB2
base_dir = str(pl.Path.cwd().parent)
python_script_dir = pl.Path.cwd().parent / 'python'
swb_work_dir = pl.Path.cwd().parent / 'swb_work'
logfile_dir = pl.Path.cwd().parent / 'logfiles'
test_data_dir = pl.Path.cwd().parent / 'test_data'
tm_table_file = test_data_dir / 'Thornthwaite_soil_moisture_retention_tables__millimeters.csv'
output_dir = pl.Path.cwd().parent / 'output'
swb2_executable = str(pl.Path.cwd().parent / 'bin' /'swb2.exe')
sys.path.append(str(python_script_dir))

from swb_cell import SWBCell
import run_management as rm

# %% [markdown]
# #### Read in Thornthwaite-Mather soil moisture retention table

# %%
tm_soil_moisture_retention_df = pd.read_csv(tm_table_file)

# %% [markdown]
# #### Remove and replace working directories for swb2 run

# %%
rm.destroy_model_work_output_and_logfile_dirs(base_dir=base_dir,
                                              swb_work_dir=swb_work_dir,
                                              logfile_dir=logfile_dir,
                                              output_dir=output_dir)
rm.create_model_work_output_and_logfile_dirs(base_dir=base_dir,
                                             swb_work_dir=swb_work_dir,
                                             logfile_dir=logfile_dir,
                                             output_dir=output_dir)

# %% [markdown]
# #### Make a new swb2 model run for a single cell example
#
# In the following step, a new swb2 model run is started using a pre-configured swb control file. The swb model contains a single cell. Daily weather data is a table of precipitation and tmax/tmin values. The test case is centered on the airport at Kenai, Alaska.

# %%
dry_run = False
lookup_dir_arg_text = f"--lookup_dir={str(test_data_dir)}"
weather_data_dir_arg_text = f"--weather_data_dir={str(test_data_dir)}"
output_dir_arg_text = f"--output_dir={str(output_dir)}"
logfile_dir_arg_text = f"--logfile_dir={str(logfile_dir)}"
control_file_path = str(test_data_dir / 'swb_control_file_kenai.ctl')
output_prefix = '--output_prefix=swb_kenai_'

swb_arg_text = [swb2_executable, output_dir_arg_text, lookup_dir_arg_text, weather_data_dir_arg_text, output_prefix, logfile_dir_arg_text, control_file_path]

f = open("stdout.txt", "w")

if not dry_run:
  with rm.cd(swb_work_dir):
#    p = subprocess.Popen(swb_arg_text, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    p = subprocess.Popen(swb_arg_text, stdout=f, stderr=subprocess.DEVNULL)
    p.wait()

# %% [markdown]
# #### Read in swb2 model results

# %%
swb_df = pd.read_csv(pl.Path(output_dir, 'SWB2_variable_values__Kenai_Airpt__col_1__row_1__x_150393__y_1179331.csv'))
# eliminate pesky spaces around column names
swb_df.columns = swb_df.columns.str.replace(' ', '')
swb_df.columns
# Out:
# Index(['date', 'month', 'day', 'year', 'landuse_code', 'landuse_index',
#        'soil_group', 'num_upslope_connections', 'sum_upslope_cells',
#        'solution_order', 'cell_index', 'target_index', 'awc', 'latitude',
#        'reference_ET0', 'actual_ET', 'curve_num_adj', 'gross_precip', 'inflow',
#        'runon', 'runoff', 'outflow', 'infiltration', 'snowfall',
#        'potential_snowmelt', 'snowmelt', 'interception', 'rainfall',
#        'net_rainfall', 'monthly_gross_precip', 'monthly_runoff',
#        'interception_storage', 'tmax', 'tmin', 'tmean', 'snow_storage',
#        'soil_storage', 'soil_storage_max', 'evaporable_water_storage',
#        'evaporable_water_deficit', 'delta_soil_storage',
#        'soil_moisture_deficit', 'surface_storage', 'surface_storage_excess',
#        'surface_storage_max', 'net_infiltration', 'rejected_net_infiltration',
#        'fog', 'irrigation', 'gdd', 'runoff_outside', 'pervious_fraction',
#        'storm_drain_capture', 'canopy_cover_fraction', 'crop_coefficient_kcb',
#        'cfgi', 'rooting_depth_max', 'current_rooting_depth',
#        'current_plant_height', 'actual_et_soil', 'readily_available_water',
#        'total_available_water', 'plant_stress_coef_ks',
#        'evap_reduction_coef_kr', 'surf_evap_coef_ke',
#        'fraction_exposed_and_wetted_soil', 'actual_et_impervious',
#        'actual_et_interception', 'adjusted_depletion_fraction_p', 'crop_etc',
#        'bare_soil_evap', 'direct_net_infiltration', 'direct_soil_moisture',
#        'inflowbuf1', 'inflowbuf2', 'inflowbuf3', 'inflowbuf4', 'inflowbuf5',
#        'inflowbuf_sum'],
#       dtype='object')

# %% [markdown]
# #### Convert swb Imperial units to metric

# %%
swb_df['tminf'] = swb_df.loc[:,'tmin']
swb_df['tmaxf'] = swb_df.loc[:,'tmax']
swb_df['tmeanf'] = swb_df.loc[:,'tmean']
swb_df.loc[:,'tmin'] = (swb_df.loc[:,'tmin'] - 32) / 1.8
swb_df.loc[:,'tmax'] = (swb_df.loc[:,'tmax'] - 32) / 1.8
swb_df.loc[:,'tmean'] = (swb_df.loc[:,'tmean'] - 32) / 1.8
swb_df.loc[:,'gross_precip'] = swb_df.loc[:,'gross_precip'] * 25.4
swb_df.loc[:,'rainfall'] = swb_df.loc[:,'rainfall'] * 25.4
swb_df.loc[:,'actual_ET'] = swb_df.loc[:,'actual_ET'] * 25.4
swb_df.loc[:,'reference_ET0'] = swb_df.loc[:,'reference_ET0'] * 25.4
swb_df.loc[:,'soil_storage'] = swb_df.loc[:,'soil_storage'] * 25.4
swb_df.loc[:,'snow_storage'] = swb_df.loc[:,'snow_storage'] * 25.4
swb_df.loc[:,'snowfall'] = swb_df.loc[:,'snowfall'] * 25.4
swb_df.loc[:,'snowmelt'] = swb_df.loc[:,'snowmelt'] * 25.4
swb_df.loc[:,'net_infiltration'] = swb_df.loc[:,'net_infiltration'] * 25.4
swb_df.loc[:,'infiltration'] = swb_df.loc[:,'infiltration'] * 25.4

swb_df['date'] = pd.to_datetime(swb_df['date'])

# %% [markdown]
# #### Create a Python versions of a swb2 cell
#
# Three simple Python implementations of a SWB cell are created here. The implementations differ only in the way that the soil-moisture-retention relations are implemented.
#
# The three Thornthwaite-Mather implementations are:
# 1. 'tm_exp': soil moisture extraction is determined by means of a simple exponential relation,
# 2. 'tm_table': soil moisture extraction is determined by looking up daily retention values in the Thornthwaite-Mather soil moisture retention tables, and
# 3. 'tm_eqns': soil moisture extraction is determined by applying a set of equations fitted to the original Thornthwaite-Mather soil moisture retention tables.
#
# The current method of choice in the compiled SWB2 code uses a simple exponential relation. Previous versions of the code used table values directly (SWB1), or used fitted equations to approximate the table values (SWB2).

# %%
# swb2 still uses Imperial units (inches and feet); the Python code expects metric units (mm and m).
# The example control file we're using for swb2 specifies 3.6 inches/foot for the available water capacity.
# 3.6 inches per foot equals 300 mm/m. The rooting depth is specified in the swb2 lookup table as 1.6404 feet, 
# or 1.6404 ft / 3.2808 ft/m = 0.5 m
mycell_exp = SWBCell(latitude=60.57154, available_water_capacity=300., rooting_depth=1.0, calculation_method='tm_exp')

mycell_tab = SWBCell(latitude=60.57154, available_water_capacity=300., rooting_depth=1.0, calculation_method='tm_table',
                    thornthwaite_mather_df=tm_soil_moisture_retention_df)

mycell_eqns = SWBCell(latitude=60.57154, available_water_capacity=300., rooting_depth=1.0, calculation_method='tm_eqns')

# %% [markdown]
# #### Initialize Python versions of swb

# %%
mycell_exp.init_swb_cell()
mycell_tab.init_swb_cell()
mycell_eqns.init_swb_cell()

# %% [markdown]
# #### Iterate and solve the water budget in Python over the date range contained in the swb2 output file
# There are three Python versions. The first uses an exponential decay function to approximate the Thornthwaite-Mather (TM) soil moisture retention tables. The second version actually looks up the TM table values directly; the third method uses a set of fitted equations to interpolate between table values.

# %%
for index, row in swb_df.iterrows():
    year = int(row['year'])
    month = int(row['month'])
    day = int(row['day'])
    # exponential decay to approximate TM
    mycell_exp.calc_cell_water_budget(year, month, day,
                                      row['tmin'],row['tmax'],row['tmean'],row['gross_precip'])
    mycell_exp.variables_todict()
    # TM table values read in directly
    mycell_tab.calc_cell_water_budget(year, month, day,
                                      row['tmin'],row['tmax'],row['tmean'],row['gross_precip'])
    mycell_tab.variables_todict()
    # TM tables approximated by fitted equations to interpolate between table values
    mycell_eqns.calc_cell_water_budget(year, month, day,
                                       row['tmin'],row['tmax'],row['tmean'],row['gross_precip'])
    mycell_eqns.variables_todict()
    print(f"making calculation for {year}-{month}-{day}")
# Out:
# making calculation for 1967-1-1
# making calculation for 1967-1-2
# making calculation for 1967-1-3
# making calculation for 1967-1-4
# making calculation for 1967-1-5
# making calculation for 1967-1-6
# making calculation for 1967-1-7
# making calculation for 1967-1-8
# making calculation for 1967-1-9
# making calculation for 1967-1-10
# making calculation for 1967-1-11
# making calculation for 1967-1-12
# making calculation for 1967-1-13
# making calculation for 1967-1-14
# making calculation for 1967-1-15
# making calculation for 1967-1-16
# making calculation for 1967-1-17
# making calculation for 1967-1-18
# making calculation for 1967-1-19
# making calculation for 1967-1-20
# making calculation for 1967-1-21
# making calculation for 1967-1-22
# making calculation for 1967-1-23
# making calculation for 1967-1-24
# making calculation for 1967-1-25
# making calculation for 1967-1-26
# making calculation for 1967-1-27
# making calculation for 1967-1-28
# making calculation for 1967-1-29
# making calculation for 1967-1-30
# making calculation for 1967-1-31
# making calculation for 1967-2-1
# making calculation for 1967-2-2
# making calculation for 1967-2-3
# making calculation for 1967-2-4
# making calculation for 1967-2-5
# making calculation for 1967-2-6
# making calculation for 1967-2-7
# making calculation for 1967-2-8
# making calculation for 1967-2-9
# making calculation for 1967-2-10
# making calculation for 1967-2-11
# making calculation for 1967-2-12
# making calculation for 1967-2-13
# making calculation for 1967-2-14
# making calculation for 1967-2-15
# making calculation for 1967-2-16
# making calculation for 1967-2-17
# making calculation for 1967-2-18
# making calculation for 1967-2-19
# making calculation for 1967-2-20
# making calculation for 1967-2-21
# making calculation for 1967-2-22
# making calculation for 1967-2-23
# making calculation for 1967-2-24
# making calculation for 1967-2-25
# making calculation for 1967-2-26
# making calculation for 1967-2-27
# making calculation for 1967-2-28
# making calculation for 1967-3-1
# making calculation for 1967-3-2
# making calculation for 1967-3-3
# making calculation for 1967-3-4
# making calculation for 1967-3-5
# making calculation for 1967-3-6
# making calculation for 1967-3-7
# making calculation for 1967-3-8
# making calculation for 1967-3-9
# making calculation for 1967-3-10
# making calculation for 1967-3-11
# making calculation for 1967-3-12
# making calculation for 1967-3-13
# making calculation for 1967-3-14
# making calculation for 1967-3-15
# making calculation for 1967-3-16
# making calculation for 1967-3-17
# making calculation for 1967-3-18
# making calculation for 1967-3-19
# making calculation for 1967-3-20
# making calculation for 1967-3-21
# making calculation for 1967-3-22
# making calculation for 1967-3-23
# making calculation for 1967-3-24
# making calculation for 1967-3-25
# making calculation for 1967-3-26
# making calculation for 1967-3-27
# making calculation for 1967-3-28
# making calculation for 1967-3-29
# making calculation for 1967-3-30
# making calculation for 1967-3-31
# making calculation for 1967-4-1
# making calculation for 1967-4-2
# making calculation for 1967-4-3
# making calculation for 1967-4-4
# making calculation for 1967-4-5
# making calculation for 1967-4-6
# making calculation for 1967-4-7
# making calculation for 1967-4-8
# making calculation for 1967-4-9
# making calculation for 1967-4-10
# making calculation for 1967-4-11
# making calculation for 1967-4-12
# making calculation for 1967-4-13
# making calculation for 1967-4-14
# making calculation for 1967-4-15
# making calculation for 1967-4-16
# making calculation for 1967-4-17
# making calculation for 1967-4-18
# making calculation for 1967-4-19
# making calculation for 1967-4-20
# making calculation for 1967-4-21
# making calculation for 1967-4-22
# making calculation for 1967-4-23
# making calculation for 1967-4-24
# making calculation for 1967-4-25
# making calculation for 1967-4-26
# making calculation for 1967-4-27
# making calculation for 1967-4-28
# making calculation for 1967-4-29
# making calculation for 1967-4-30
# making calculation for 1967-5-1
# making calculation for 1967-5-2
# making calculation for 1967-5-3
# making calculation for 1967-5-4
# making calculation for 1967-5-5
# making calculation for 1967-5-6
# making calculation for 1967-5-7
# making calculation for 1967-5-8
# making calculation for 1967-5-9
# making calculation for 1967-5-10
# making calculation for 1967-5-11
# making calculation for 1967-5-12
# making calculation for 1967-5-13
# making calculation for 1967-5-14
# making calculation for 1967-5-15
# making calculation for 1967-5-16
# making calculation for 1967-5-17
# making calculation for 1967-5-18
# making calculation for 1967-5-19
# making calculation for 1967-5-20
# making calculation for 1967-5-21
# making calculation for 1967-5-22
# making calculation for 1967-5-23
# making calculation for 1967-5-24
# making calculation for 1967-5-25
# making calculation for 1967-5-26
# making calculation for 1967-5-27
# making calculation for 1967-5-28
# making calculation for 1967-5-29
# making calculation for 1967-5-30
# making calculation for 1967-5-31
# making calculation for 1967-6-1
# making calculation for 1967-6-2
# making calculation for 1967-6-3
# making calculation for 1967-6-4
# making calculation for 1967-6-5
# making calculation for 1967-6-6
# making calculation for 1967-6-7
# making calculation for 1967-6-8
# making calculation for 1967-6-9
# making calculation for 1967-6-10
# making calculation for 1967-6-11
# making calculation for 1967-6-12
# making calculation for 1967-6-13
# making calculation for 1967-6-14
# making calculation for 1967-6-15
# making calculation for 1967-6-16
# making calculation for 1967-6-17
# making calculation for 1967-6-18
# making calculation for 1967-6-19
# making calculation for 1967-6-20
# making calculation for 1967-6-21
# making calculation for 1967-6-22
# making calculation for 1967-6-23
# making calculation for 1967-6-24
# making calculation for 1967-6-25
# making calculation for 1967-6-26
# making calculation for 1967-6-27
# making calculation for 1967-6-28
# making calculation for 1967-6-29
# making calculation for 1967-6-30
# making calculation for 1967-7-1
# making calculation for 1967-7-2
# making calculation for 1967-7-3
# making calculation for 1967-7-4
# making calculation for 1967-7-5
# making calculation for 1967-7-6
# making calculation for 1967-7-7
# making calculation for 1967-7-8
# making calculation for 1967-7-9
# making calculation for 1967-7-10
# making calculation for 1967-7-11
# making calculation for 1967-7-12
# making calculation for 1967-7-13
# making calculation for 1967-7-14
# making calculation for 1967-7-15
# making calculation for 1967-7-16
# making calculation for 1967-7-17
# making calculation for 1967-7-18
# making calculation for 1967-7-19
# making calculation for 1967-7-20
# making calculation for 1967-7-21
# making calculation for 1967-7-22
# making calculation for 1967-7-23
# making calculation for 1967-7-24
# making calculation for 1967-7-25
# making calculation for 1967-7-26
# making calculation for 1967-7-27
# making calculation for 1967-7-28
# making calculation for 1967-7-29
# making calculation for 1967-7-30
# making calculation for 1967-7-31
# making calculation for 1967-8-1
# making calculation for 1967-8-2
# making calculation for 1967-8-3
# making calculation for 1967-8-4
# making calculation for 1967-8-5
# making calculation for 1967-8-6
# making calculation for 1967-8-7
# making calculation for 1967-8-8
# making calculation for 1967-8-9
# making calculation for 1967-8-10
# making calculation for 1967-8-11
# making calculation for 1967-8-12
# making calculation for 1967-8-13
# making calculation for 1967-8-14
# making calculation for 1967-8-15
# making calculation for 1967-8-16
# making calculation for 1967-8-17
# making calculation for 1967-8-18
# making calculation for 1967-8-19
# making calculation for 1967-8-20
# making calculation for 1967-8-21
# making calculation for 1967-8-22
# making calculation for 1967-8-23
# making calculation for 1967-8-24
# making calculation for 1967-8-25
# making calculation for 1967-8-26
# making calculation for 1967-8-27
# making calculation for 1967-8-28
# making calculation for 1967-8-29
# making calculation for 1967-8-30
# making calculation for 1967-8-31
# making calculation for 1967-9-1
# making calculation for 1967-9-2
# making calculation for 1967-9-3
# making calculation for 1967-9-4
# making calculation for 1967-9-5
# making calculation for 1967-9-6
# making calculation for 1967-9-7
# making calculation for 1967-9-8
# making calculation for 1967-9-9
# making calculation for 1967-9-10
# making calculation for 1967-9-11
# making calculation for 1967-9-12
# making calculation for 1967-9-13
# making calculation for 1967-9-14
# making calculation for 1967-9-15
# making calculation for 1967-9-16
# making calculation for 1967-9-17
# making calculation for 1967-9-18
# making calculation for 1967-9-19
# making calculation for 1967-9-20
# making calculation for 1967-9-21
# making calculation for 1967-9-22
# making calculation for 1967-9-23
# making calculation for 1967-9-24
# making calculation for 1967-9-25
# making calculation for 1967-9-26
# making calculation for 1967-9-27
# making calculation for 1967-9-28
# making calculation for 1967-9-29
# making calculation for 1967-9-30
# making calculation for 1967-10-1
# making calculation for 1967-10-2
# making calculation for 1967-10-3
# making calculation for 1967-10-4
# making calculation for 1967-10-5
# making calculation for 1967-10-6
# making calculation for 1967-10-7
# making calculation for 1967-10-8
# making calculation for 1967-10-9
# making calculation for 1967-10-10
# making calculation for 1967-10-11
# making calculation for 1967-10-12
# making calculation for 1967-10-13
# making calculation for 1967-10-14
# making calculation for 1967-10-15
# making calculation for 1967-10-16
# making calculation for 1967-10-17
# making calculation for 1967-10-18
# making calculation for 1967-10-19
# making calculation for 1967-10-20
# making calculation for 1967-10-21
# making calculation for 1967-10-22
# making calculation for 1967-10-23
# making calculation for 1967-10-24
# making calculation for 1967-10-25
# making calculation for 1967-10-26
# making calculation for 1967-10-27
# making calculation for 1967-10-28
# making calculation for 1967-10-29
# making calculation for 1967-10-30
# making calculation for 1967-10-31
# making calculation for 1967-11-1
# making calculation for 1967-11-2
# making calculation for 1967-11-3
# making calculation for 1967-11-4
# making calculation for 1967-11-5
# making calculation for 1967-11-6
# making calculation for 1967-11-7
# making calculation for 1967-11-8
# making calculation for 1967-11-9
# making calculation for 1967-11-10
# making calculation for 1967-11-11
# making calculation for 1967-11-12
# making calculation for 1967-11-13
# making calculation for 1967-11-14
# making calculation for 1967-11-15
# making calculation for 1967-11-16
# making calculation for 1967-11-17
# making calculation for 1967-11-18
# making calculation for 1967-11-19
# making calculation for 1967-11-20
# making calculation for 1967-11-21
# making calculation for 1967-11-22
# making calculation for 1967-11-23
# making calculation for 1967-11-24
# making calculation for 1967-11-25
# making calculation for 1967-11-26
# making calculation for 1967-11-27
# making calculation for 1967-11-28
# making calculation for 1967-11-29
# making calculation for 1967-11-30
# making calculation for 1967-12-1
# making calculation for 1967-12-2
# making calculation for 1967-12-3
# making calculation for 1967-12-4
# making calculation for 1967-12-5
# making calculation for 1967-12-6
# making calculation for 1967-12-7
# making calculation for 1967-12-8
# making calculation for 1967-12-9
# making calculation for 1967-12-10
# making calculation for 1967-12-11
# making calculation for 1967-12-12
# making calculation for 1967-12-13
# making calculation for 1967-12-14
# making calculation for 1967-12-15
# making calculation for 1967-12-16
# making calculation for 1967-12-17
# making calculation for 1967-12-18
# making calculation for 1967-12-19
# making calculation for 1967-12-20
# making calculation for 1967-12-21
# making calculation for 1967-12-22
# making calculation for 1967-12-23
# making calculation for 1967-12-24
# making calculation for 1967-12-25
# making calculation for 1967-12-26
# making calculation for 1967-12-27
# making calculation for 1967-12-28
# making calculation for 1967-12-29
# making calculation for 1967-12-30
# making calculation for 1967-12-31
# making calculation for 1968-1-1
# making calculation for 1968-1-2
# making calculation for 1968-1-3
# making calculation for 1968-1-4
# making calculation for 1968-1-5
# making calculation for 1968-1-6
# making calculation for 1968-1-7
# making calculation for 1968-1-8
# making calculation for 1968-1-9
# making calculation for 1968-1-10
# making calculation for 1968-1-11
# making calculation for 1968-1-12
# making calculation for 1968-1-13
# making calculation for 1968-1-14
# making calculation for 1968-1-15
# making calculation for 1968-1-16
# making calculation for 1968-1-17
# making calculation for 1968-1-18
# making calculation for 1968-1-19
# making calculation for 1968-1-20
# making calculation for 1968-1-21
# making calculation for 1968-1-22
# making calculation for 1968-1-23
# making calculation for 1968-1-24
# making calculation for 1968-1-25
# making calculation for 1968-1-26
# making calculation for 1968-1-27
# making calculation for 1968-1-28
# making calculation for 1968-1-29
# making calculation for 1968-1-30
# making calculation for 1968-1-31
# making calculation for 1968-2-1
# making calculation for 1968-2-2
# making calculation for 1968-2-3
# making calculation for 1968-2-4
# making calculation for 1968-2-5
# making calculation for 1968-2-6
# making calculation for 1968-2-7
# making calculation for 1968-2-8
# making calculation for 1968-2-9
# making calculation for 1968-2-10
# making calculation for 1968-2-11
# making calculation for 1968-2-12
# making calculation for 1968-2-13
# making calculation for 1968-2-14
# making calculation for 1968-2-15
# making calculation for 1968-2-16
# making calculation for 1968-2-17
# making calculation for 1968-2-18
# making calculation for 1968-2-19
# making calculation for 1968-2-20
# making calculation for 1968-2-21
# making calculation for 1968-2-22
# making calculation for 1968-2-23
# making calculation for 1968-2-24
# making calculation for 1968-2-25
# making calculation for 1968-2-26
# making calculation for 1968-2-27
# making calculation for 1968-2-28
# making calculation for 1968-2-29
# making calculation for 1968-3-1
# making calculation for 1968-3-2
# making calculation for 1968-3-3
# making calculation for 1968-3-4
# making calculation for 1968-3-5
# making calculation for 1968-3-6
# making calculation for 1968-3-7
# making calculation for 1968-3-8
# making calculation for 1968-3-9
# making calculation for 1968-3-10
# making calculation for 1968-3-11
# making calculation for 1968-3-12
# making calculation for 1968-3-13
# making calculation for 1968-3-14
# making calculation for 1968-3-15
# making calculation for 1968-3-16
# making calculation for 1968-3-17
# making calculation for 1968-3-18
# making calculation for 1968-3-19
# making calculation for 1968-3-20
# making calculation for 1968-3-21
# making calculation for 1968-3-22
# making calculation for 1968-3-23
# making calculation for 1968-3-24
# making calculation for 1968-3-25
# making calculation for 1968-3-26
# making calculation for 1968-3-27
# making calculation for 1968-3-28
# making calculation for 1968-3-29
# making calculation for 1968-3-30
# making calculation for 1968-3-31
# making calculation for 1968-4-1
# making calculation for 1968-4-2
# making calculation for 1968-4-3
# making calculation for 1968-4-4
# making calculation for 1968-4-5
# making calculation for 1968-4-6
# making calculation for 1968-4-7
# making calculation for 1968-4-8
# making calculation for 1968-4-9
# making calculation for 1968-4-10
# making calculation for 1968-4-11
# making calculation for 1968-4-12
# making calculation for 1968-4-13
# making calculation for 1968-4-14
# making calculation for 1968-4-15
# making calculation for 1968-4-16
# making calculation for 1968-4-17
# making calculation for 1968-4-18
# making calculation for 1968-4-19
# making calculation for 1968-4-20
# making calculation for 1968-4-21
# making calculation for 1968-4-22
# making calculation for 1968-4-23
# making calculation for 1968-4-24
# making calculation for 1968-4-25
# making calculation for 1968-4-26
# making calculation for 1968-4-27
# making calculation for 1968-4-28
# making calculation for 1968-4-29
# making calculation for 1968-4-30
# making calculation for 1968-5-1
# making calculation for 1968-5-2
# making calculation for 1968-5-3
# making calculation for 1968-5-4
# making calculation for 1968-5-5
# making calculation for 1968-5-6
# making calculation for 1968-5-7
# making calculation for 1968-5-8
# making calculation for 1968-5-9
# making calculation for 1968-5-10
# making calculation for 1968-5-11
# making calculation for 1968-5-12
# making calculation for 1968-5-13
# making calculation for 1968-5-14
# making calculation for 1968-5-15
# making calculation for 1968-5-16
# making calculation for 1968-5-17
# making calculation for 1968-5-18
# making calculation for 1968-5-19
# making calculation for 1968-5-20
# making calculation for 1968-5-21
# making calculation for 1968-5-22
# making calculation for 1968-5-23
# making calculation for 1968-5-24
# making calculation for 1968-5-25
# making calculation for 1968-5-26
# making calculation for 1968-5-27
# making calculation for 1968-5-28
# making calculation for 1968-5-29
# making calculation for 1968-5-30
# making calculation for 1968-5-31
# making calculation for 1968-6-1
# making calculation for 1968-6-2
# making calculation for 1968-6-3
# making calculation for 1968-6-4
# making calculation for 1968-6-5
# making calculation for 1968-6-6
# making calculation for 1968-6-7
# making calculation for 1968-6-8
# making calculation for 1968-6-9
# making calculation for 1968-6-10
# making calculation for 1968-6-11
# making calculation for 1968-6-12
# making calculation for 1968-6-13
# making calculation for 1968-6-14
# making calculation for 1968-6-15
# making calculation for 1968-6-16
# making calculation for 1968-6-17
# making calculation for 1968-6-18
# making calculation for 1968-6-19
# making calculation for 1968-6-20
# making calculation for 1968-6-21
# making calculation for 1968-6-22
# making calculation for 1968-6-23
# making calculation for 1968-6-24
# making calculation for 1968-6-25
# making calculation for 1968-6-26
# making calculation for 1968-6-27
# making calculation for 1968-6-28
# making calculation for 1968-6-29
# making calculation for 1968-6-30
# making calculation for 1968-7-1
# making calculation for 1968-7-2
# making calculation for 1968-7-3
# making calculation for 1968-7-4
# making calculation for 1968-7-5
# making calculation for 1968-7-6
# making calculation for 1968-7-7
# making calculation for 1968-7-8
# making calculation for 1968-7-9
# making calculation for 1968-7-10
# making calculation for 1968-7-11
# making calculation for 1968-7-12
# making calculation for 1968-7-13
# making calculation for 1968-7-14
# making calculation for 1968-7-15
# making calculation for 1968-7-16
# making calculation for 1968-7-17
# making calculation for 1968-7-18
# making calculation for 1968-7-19
# making calculation for 1968-7-20
# making calculation for 1968-7-21
# making calculation for 1968-7-22
# making calculation for 1968-7-23
# making calculation for 1968-7-24
# making calculation for 1968-7-25
# making calculation for 1968-7-26
# making calculation for 1968-7-27
# making calculation for 1968-7-28
# making calculation for 1968-7-29
# making calculation for 1968-7-30
# making calculation for 1968-7-31
# making calculation for 1968-8-1
# making calculation for 1968-8-2
# making calculation for 1968-8-3
# making calculation for 1968-8-4
# making calculation for 1968-8-5
# making calculation for 1968-8-6
# making calculation for 1968-8-7
# making calculation for 1968-8-8
# making calculation for 1968-8-9
# making calculation for 1968-8-10
# making calculation for 1968-8-11
# making calculation for 1968-8-12
# making calculation for 1968-8-13
# making calculation for 1968-8-14
# making calculation for 1968-8-15
# making calculation for 1968-8-16
# making calculation for 1968-8-17
# making calculation for 1968-8-18
# making calculation for 1968-8-19
# making calculation for 1968-8-20
# making calculation for 1968-8-21
# making calculation for 1968-8-22
# making calculation for 1968-8-23
# making calculation for 1968-8-24
# making calculation for 1968-8-25
# making calculation for 1968-8-26
# making calculation for 1968-8-27
# making calculation for 1968-8-28
# making calculation for 1968-8-29
# making calculation for 1968-8-30
# making calculation for 1968-8-31
# making calculation for 1968-9-1
# making calculation for 1968-9-2
# making calculation for 1968-9-3
# making calculation for 1968-9-4
# making calculation for 1968-9-5
# making calculation for 1968-9-6
# making calculation for 1968-9-7
# making calculation for 1968-9-8
# making calculation for 1968-9-9
# making calculation for 1968-9-10
# making calculation for 1968-9-11
# making calculation for 1968-9-12
# making calculation for 1968-9-13
# making calculation for 1968-9-14
# making calculation for 1968-9-15
# making calculation for 1968-9-16
# making calculation for 1968-9-17
# making calculation for 1968-9-18
# making calculation for 1968-9-19
# making calculation for 1968-9-20
# making calculation for 1968-9-21
# making calculation for 1968-9-22
# making calculation for 1968-9-23
# making calculation for 1968-9-24
# making calculation for 1968-9-25
# making calculation for 1968-9-26
# making calculation for 1968-9-27
# making calculation for 1968-9-28
# making calculation for 1968-9-29
# making calculation for 1968-9-30
# making calculation for 1968-10-1
# making calculation for 1968-10-2
# making calculation for 1968-10-3
# making calculation for 1968-10-4
# making calculation for 1968-10-5
# making calculation for 1968-10-6
# making calculation for 1968-10-7
# making calculation for 1968-10-8
# making calculation for 1968-10-9
# making calculation for 1968-10-10
# making calculation for 1968-10-11
# making calculation for 1968-10-12
# making calculation for 1968-10-13
# making calculation for 1968-10-14
# making calculation for 1968-10-15
# making calculation for 1968-10-16
# making calculation for 1968-10-17
# making calculation for 1968-10-18
# making calculation for 1968-10-19
# making calculation for 1968-10-20
# making calculation for 1968-10-21
# making calculation for 1968-10-22
# making calculation for 1968-10-23
# making calculation for 1968-10-24
# making calculation for 1968-10-25
# making calculation for 1968-10-26
# making calculation for 1968-10-27
# making calculation for 1968-10-28
# making calculation for 1968-10-29
# making calculation for 1968-10-30
# making calculation for 1968-10-31
# making calculation for 1968-11-1
# making calculation for 1968-11-2
# making calculation for 1968-11-3
# making calculation for 1968-11-4
# making calculation for 1968-11-5
# making calculation for 1968-11-6
# making calculation for 1968-11-7
# making calculation for 1968-11-8
# making calculation for 1968-11-9
# making calculation for 1968-11-10
# making calculation for 1968-11-11
# making calculation for 1968-11-12
# making calculation for 1968-11-13
# making calculation for 1968-11-14
# making calculation for 1968-11-15
# making calculation for 1968-11-16
# making calculation for 1968-11-17
# making calculation for 1968-11-18
# making calculation for 1968-11-19
# making calculation for 1968-11-20
# making calculation for 1968-11-21
# making calculation for 1968-11-22
# making calculation for 1968-11-23
# making calculation for 1968-11-24
# making calculation for 1968-11-25
# making calculation for 1968-11-26
# making calculation for 1968-11-27
# making calculation for 1968-11-28
# making calculation for 1968-11-29
# making calculation for 1968-11-30
# making calculation for 1968-12-1
# making calculation for 1968-12-2
# making calculation for 1968-12-3
# making calculation for 1968-12-4
# making calculation for 1968-12-5
# making calculation for 1968-12-6
# making calculation for 1968-12-7
# making calculation for 1968-12-8
# making calculation for 1968-12-9
# making calculation for 1968-12-10
# making calculation for 1968-12-11
# making calculation for 1968-12-12
# making calculation for 1968-12-13
# making calculation for 1968-12-14
# making calculation for 1968-12-15
# making calculation for 1968-12-16
# making calculation for 1968-12-17
# making calculation for 1968-12-18
# making calculation for 1968-12-19
# making calculation for 1968-12-20
# making calculation for 1968-12-21
# making calculation for 1968-12-22
# making calculation for 1968-12-23
# making calculation for 1968-12-24
# making calculation for 1968-12-25
# making calculation for 1968-12-26
# making calculation for 1968-12-27
# making calculation for 1968-12-28
# making calculation for 1968-12-29
# making calculation for 1968-12-30
# making calculation for 1968-12-31
# making calculation for 1969-1-1
# making calculation for 1969-1-2
# making calculation for 1969-1-3
# making calculation for 1969-1-4
# making calculation for 1969-1-5
# making calculation for 1969-1-6
# making calculation for 1969-1-7
# making calculation for 1969-1-8
# making calculation for 1969-1-9
# making calculation for 1969-1-10
# making calculation for 1969-1-11
# making calculation for 1969-1-12
# making calculation for 1969-1-13
# making calculation for 1969-1-14
# making calculation for 1969-1-15
# making calculation for 1969-1-16
# making calculation for 1969-1-17
# making calculation for 1969-1-18
# making calculation for 1969-1-19
# making calculation for 1969-1-20
# making calculation for 1969-1-21
# making calculation for 1969-1-22
# making calculation for 1969-1-23
# making calculation for 1969-1-24
# making calculation for 1969-1-25
# making calculation for 1969-1-26
# making calculation for 1969-1-27
# making calculation for 1969-1-28
# making calculation for 1969-1-29
# making calculation for 1969-1-30
# making calculation for 1969-1-31
# making calculation for 1969-2-1
# making calculation for 1969-2-2
# making calculation for 1969-2-3
# making calculation for 1969-2-4
# making calculation for 1969-2-5
# making calculation for 1969-2-6
# making calculation for 1969-2-7
# making calculation for 1969-2-8
# making calculation for 1969-2-9
# making calculation for 1969-2-10
# making calculation for 1969-2-11
# making calculation for 1969-2-12
# making calculation for 1969-2-13
# making calculation for 1969-2-14
# making calculation for 1969-2-15
# making calculation for 1969-2-16
# making calculation for 1969-2-17
# making calculation for 1969-2-18
# making calculation for 1969-2-19
# making calculation for 1969-2-20
# making calculation for 1969-2-21
# making calculation for 1969-2-22
# making calculation for 1969-2-23
# making calculation for 1969-2-24
# making calculation for 1969-2-25
# making calculation for 1969-2-26
# making calculation for 1969-2-27
# making calculation for 1969-2-28
# making calculation for 1969-3-1
# making calculation for 1969-3-2
# making calculation for 1969-3-3
# making calculation for 1969-3-4
# making calculation for 1969-3-5
# making calculation for 1969-3-6
# making calculation for 1969-3-7
# making calculation for 1969-3-8
# making calculation for 1969-3-9
# making calculation for 1969-3-10
# making calculation for 1969-3-11
# making calculation for 1969-3-12
# making calculation for 1969-3-13
# making calculation for 1969-3-14
# making calculation for 1969-3-15
# making calculation for 1969-3-16
# making calculation for 1969-3-17
# making calculation for 1969-3-18
# making calculation for 1969-3-19
# making calculation for 1969-3-20
# making calculation for 1969-3-21
# making calculation for 1969-3-22
# making calculation for 1969-3-23
# making calculation for 1969-3-24
# making calculation for 1969-3-25
# making calculation for 1969-3-26
# making calculation for 1969-3-27
# making calculation for 1969-3-28
# making calculation for 1969-3-29
# making calculation for 1969-3-30
# making calculation for 1969-3-31
# making calculation for 1969-4-1
# making calculation for 1969-4-2
# making calculation for 1969-4-3
# making calculation for 1969-4-4
# making calculation for 1969-4-5
# making calculation for 1969-4-6
# making calculation for 1969-4-7
# making calculation for 1969-4-8
# making calculation for 1969-4-9
# making calculation for 1969-4-10
# making calculation for 1969-4-11
# making calculation for 1969-4-12
# making calculation for 1969-4-13
# making calculation for 1969-4-14
# making calculation for 1969-4-15
# making calculation for 1969-4-16
# making calculation for 1969-4-17
# making calculation for 1969-4-18
# making calculation for 1969-4-19
# making calculation for 1969-4-20
# making calculation for 1969-4-21
# making calculation for 1969-4-22
# making calculation for 1969-4-23
# making calculation for 1969-4-24
# making calculation for 1969-4-25
# making calculation for 1969-4-26
# making calculation for 1969-4-27
# making calculation for 1969-4-28
# making calculation for 1969-4-29
# making calculation for 1969-4-30
# making calculation for 1969-5-1
# making calculation for 1969-5-2
# making calculation for 1969-5-3
# making calculation for 1969-5-4
# making calculation for 1969-5-5
# making calculation for 1969-5-6
# making calculation for 1969-5-7
# making calculation for 1969-5-8
# making calculation for 1969-5-9
# making calculation for 1969-5-10
# making calculation for 1969-5-11
# making calculation for 1969-5-12
# making calculation for 1969-5-13
# making calculation for 1969-5-14
# making calculation for 1969-5-15
# making calculation for 1969-5-16
# making calculation for 1969-5-17
# making calculation for 1969-5-18
# making calculation for 1969-5-19
# making calculation for 1969-5-20
# making calculation for 1969-5-21
# making calculation for 1969-5-22
# making calculation for 1969-5-23
# making calculation for 1969-5-24
# making calculation for 1969-5-25
# making calculation for 1969-5-26
# making calculation for 1969-5-27
# making calculation for 1969-5-28
# making calculation for 1969-5-29
# making calculation for 1969-5-30
# making calculation for 1969-5-31
# making calculation for 1969-6-1
# making calculation for 1969-6-2
# making calculation for 1969-6-3
# making calculation for 1969-6-4
# making calculation for 1969-6-5
# making calculation for 1969-6-6
# making calculation for 1969-6-7
# making calculation for 1969-6-8
# making calculation for 1969-6-9
# making calculation for 1969-6-10
# making calculation for 1969-6-11
# making calculation for 1969-6-12
# making calculation for 1969-6-13
# making calculation for 1969-6-14
# making calculation for 1969-6-15
# making calculation for 1969-6-16
# making calculation for 1969-6-17
# making calculation for 1969-6-18
# making calculation for 1969-6-19
# making calculation for 1969-6-20
# making calculation for 1969-6-21
# making calculation for 1969-6-22
# making calculation for 1969-6-23
# making calculation for 1969-6-24
# making calculation for 1969-6-25
# making calculation for 1969-6-26
# making calculation for 1969-6-27
# making calculation for 1969-6-28
# making calculation for 1969-6-29
# making calculation for 1969-6-30
# making calculation for 1969-7-1
# making calculation for 1969-7-2
# making calculation for 1969-7-3
# making calculation for 1969-7-4
# making calculation for 1969-7-5
# making calculation for 1969-7-6
# making calculation for 1969-7-7
# making calculation for 1969-7-8
# making calculation for 1969-7-9
# making calculation for 1969-7-10
# making calculation for 1969-7-11
# making calculation for 1969-7-12
# making calculation for 1969-7-13
# making calculation for 1969-7-14
# making calculation for 1969-7-15
# making calculation for 1969-7-16
# making calculation for 1969-7-17
# making calculation for 1969-7-18
# making calculation for 1969-7-19
# making calculation for 1969-7-20
# making calculation for 1969-7-21
# making calculation for 1969-7-22
# making calculation for 1969-7-23
# making calculation for 1969-7-24
# making calculation for 1969-7-25
# making calculation for 1969-7-26
# making calculation for 1969-7-27
# making calculation for 1969-7-28
# making calculation for 1969-7-29
# making calculation for 1969-7-30
# making calculation for 1969-7-31
# making calculation for 1969-8-1
# making calculation for 1969-8-2
# making calculation for 1969-8-3
# making calculation for 1969-8-4
# making calculation for 1969-8-5
# making calculation for 1969-8-6
# making calculation for 1969-8-7
# making calculation for 1969-8-8
# making calculation for 1969-8-9
# making calculation for 1969-8-10
# making calculation for 1969-8-11
# making calculation for 1969-8-12
# making calculation for 1969-8-13
# making calculation for 1969-8-14
# making calculation for 1969-8-15
# making calculation for 1969-8-16
# making calculation for 1969-8-17
# making calculation for 1969-8-18
# making calculation for 1969-8-19
# making calculation for 1969-8-20
# making calculation for 1969-8-21
# making calculation for 1969-8-22
# making calculation for 1969-8-23
# making calculation for 1969-8-24
# making calculation for 1969-8-25
# making calculation for 1969-8-26
# making calculation for 1969-8-27
# making calculation for 1969-8-28
# making calculation for 1969-8-29
# making calculation for 1969-8-30
# making calculation for 1969-8-31
# making calculation for 1969-9-1
# making calculation for 1969-9-2
# making calculation for 1969-9-3
# making calculation for 1969-9-4
# making calculation for 1969-9-5
# making calculation for 1969-9-6
# making calculation for 1969-9-7
# making calculation for 1969-9-8
# making calculation for 1969-9-9
# making calculation for 1969-9-10
# making calculation for 1969-9-11
# making calculation for 1969-9-12
# making calculation for 1969-9-13
# making calculation for 1969-9-14
# making calculation for 1969-9-15
# making calculation for 1969-9-16
# making calculation for 1969-9-17
# making calculation for 1969-9-18
# making calculation for 1969-9-19
# making calculation for 1969-9-20
# making calculation for 1969-9-21
# making calculation for 1969-9-22
# making calculation for 1969-9-23
# making calculation for 1969-9-24
# making calculation for 1969-9-25
# making calculation for 1969-9-26
# making calculation for 1969-9-27
# making calculation for 1969-9-28
# making calculation for 1969-9-29
# making calculation for 1969-9-30
# making calculation for 1969-10-1
# making calculation for 1969-10-2
# making calculation for 1969-10-3
# making calculation for 1969-10-4
# making calculation for 1969-10-5
# making calculation for 1969-10-6
# making calculation for 1969-10-7
# making calculation for 1969-10-8
# making calculation for 1969-10-9
# making calculation for 1969-10-10
# making calculation for 1969-10-11
# making calculation for 1969-10-12
# making calculation for 1969-10-13
# making calculation for 1969-10-14
# making calculation for 1969-10-15
# making calculation for 1969-10-16
# making calculation for 1969-10-17
# making calculation for 1969-10-18
# making calculation for 1969-10-19
# making calculation for 1969-10-20
# making calculation for 1969-10-21
# making calculation for 1969-10-22
# making calculation for 1969-10-23
# making calculation for 1969-10-24
# making calculation for 1969-10-25
# making calculation for 1969-10-26
# making calculation for 1969-10-27
# making calculation for 1969-10-28
# making calculation for 1969-10-29
# making calculation for 1969-10-30
# making calculation for 1969-10-31
# making calculation for 1969-11-1
# making calculation for 1969-11-2
# making calculation for 1969-11-3
# making calculation for 1969-11-4
# making calculation for 1969-11-5
# making calculation for 1969-11-6
# making calculation for 1969-11-7
# making calculation for 1969-11-8
# making calculation for 1969-11-9
# making calculation for 1969-11-10
# making calculation for 1969-11-11
# making calculation for 1969-11-12
# making calculation for 1969-11-13
# making calculation for 1969-11-14
# making calculation for 1969-11-15
# making calculation for 1969-11-16
# making calculation for 1969-11-17
# making calculation for 1969-11-18
# making calculation for 1969-11-19
# making calculation for 1969-11-20
# making calculation for 1969-11-21
# making calculation for 1969-11-22
# making calculation for 1969-11-23
# making calculation for 1969-11-24
# making calculation for 1969-11-25
# making calculation for 1969-11-26
# making calculation for 1969-11-27
# making calculation for 1969-11-28
# making calculation for 1969-11-29
# making calculation for 1969-11-30
# making calculation for 1969-12-1
# making calculation for 1969-12-2
# making calculation for 1969-12-3
# making calculation for 1969-12-4
# making calculation for 1969-12-5
# making calculation for 1969-12-6
# making calculation for 1969-12-7
# making calculation for 1969-12-8
# making calculation for 1969-12-9
# making calculation for 1969-12-10
# making calculation for 1969-12-11
# making calculation for 1969-12-12
# making calculation for 1969-12-13
# making calculation for 1969-12-14
# making calculation for 1969-12-15
# making calculation for 1969-12-16
# making calculation for 1969-12-17
# making calculation for 1969-12-18
# making calculation for 1969-12-19
# making calculation for 1969-12-20
# making calculation for 1969-12-21
# making calculation for 1969-12-22
# making calculation for 1969-12-23
# making calculation for 1969-12-24
# making calculation for 1969-12-25
# making calculation for 1969-12-26
# making calculation for 1969-12-27
# making calculation for 1969-12-28
# making calculation for 1969-12-29
# making calculation for 1969-12-30
# making calculation for 1969-12-31
# making calculation for 1970-1-1
# making calculation for 1970-1-2
# making calculation for 1970-1-3
# making calculation for 1970-1-4
# making calculation for 1970-1-5
# making calculation for 1970-1-6
# making calculation for 1970-1-7
# making calculation for 1970-1-8
# making calculation for 1970-1-9
# making calculation for 1970-1-10
# making calculation for 1970-1-11
# making calculation for 1970-1-12
# making calculation for 1970-1-13
# making calculation for 1970-1-14
# making calculation for 1970-1-15
# making calculation for 1970-1-16
# making calculation for 1970-1-17
# making calculation for 1970-1-18
# making calculation for 1970-1-19
# making calculation for 1970-1-20
# making calculation for 1970-1-21
# making calculation for 1970-1-22
# making calculation for 1970-1-23
# making calculation for 1970-1-24
# making calculation for 1970-1-25
# making calculation for 1970-1-26
# making calculation for 1970-1-27
# making calculation for 1970-1-28
# making calculation for 1970-1-29
# making calculation for 1970-1-30
# making calculation for 1970-1-31
# making calculation for 1970-2-1
# making calculation for 1970-2-2
# making calculation for 1970-2-3
# making calculation for 1970-2-4
# making calculation for 1970-2-5
# making calculation for 1970-2-6
# making calculation for 1970-2-7
# making calculation for 1970-2-8
# making calculation for 1970-2-9
# making calculation for 1970-2-10
# making calculation for 1970-2-11
# making calculation for 1970-2-12
# making calculation for 1970-2-13
# making calculation for 1970-2-14
# making calculation for 1970-2-15
# making calculation for 1970-2-16
# making calculation for 1970-2-17
# making calculation for 1970-2-18
# making calculation for 1970-2-19
# making calculation for 1970-2-20
# making calculation for 1970-2-21
# making calculation for 1970-2-22
# making calculation for 1970-2-23
# making calculation for 1970-2-24
# making calculation for 1970-2-25
# making calculation for 1970-2-26
# making calculation for 1970-2-27
# making calculation for 1970-2-28
# making calculation for 1970-3-1
# making calculation for 1970-3-2
# making calculation for 1970-3-3
# making calculation for 1970-3-4
# making calculation for 1970-3-5
# making calculation for 1970-3-6
# making calculation for 1970-3-7
# making calculation for 1970-3-8
# making calculation for 1970-3-9
# making calculation for 1970-3-10
# making calculation for 1970-3-11
# making calculation for 1970-3-12
# making calculation for 1970-3-13
# making calculation for 1970-3-14
# making calculation for 1970-3-15
# making calculation for 1970-3-16
# making calculation for 1970-3-17
# making calculation for 1970-3-18
# making calculation for 1970-3-19
# making calculation for 1970-3-20
# making calculation for 1970-3-21
# making calculation for 1970-3-22
# making calculation for 1970-3-23
# making calculation for 1970-3-24
# making calculation for 1970-3-25
# making calculation for 1970-3-26
# making calculation for 1970-3-27
# making calculation for 1970-3-28
# making calculation for 1970-3-29
# making calculation for 1970-3-30
# making calculation for 1970-3-31
# making calculation for 1970-4-1
# making calculation for 1970-4-2
# making calculation for 1970-4-3
# making calculation for 1970-4-4
# making calculation for 1970-4-5
# making calculation for 1970-4-6
# making calculation for 1970-4-7
# making calculation for 1970-4-8
# making calculation for 1970-4-9
# making calculation for 1970-4-10
# making calculation for 1970-4-11
# making calculation for 1970-4-12
# making calculation for 1970-4-13
# making calculation for 1970-4-14
# making calculation for 1970-4-15
# making calculation for 1970-4-16
# making calculation for 1970-4-17
# making calculation for 1970-4-18
# making calculation for 1970-4-19
# making calculation for 1970-4-20
# making calculation for 1970-4-21
# making calculation for 1970-4-22
# making calculation for 1970-4-23
# making calculation for 1970-4-24
# making calculation for 1970-4-25
# making calculation for 1970-4-26
# making calculation for 1970-4-27
# making calculation for 1970-4-28
# making calculation for 1970-4-29
# making calculation for 1970-4-30
# making calculation for 1970-5-1
# making calculation for 1970-5-2
# making calculation for 1970-5-3
# making calculation for 1970-5-4
# making calculation for 1970-5-5
# making calculation for 1970-5-6
# making calculation for 1970-5-7
# making calculation for 1970-5-8
# making calculation for 1970-5-9
# making calculation for 1970-5-10
# making calculation for 1970-5-11
# making calculation for 1970-5-12
# making calculation for 1970-5-13
# making calculation for 1970-5-14
# making calculation for 1970-5-15
# making calculation for 1970-5-16
# making calculation for 1970-5-17
# making calculation for 1970-5-18
# making calculation for 1970-5-19
# making calculation for 1970-5-20
# making calculation for 1970-5-21
# making calculation for 1970-5-22
# making calculation for 1970-5-23
# making calculation for 1970-5-24
# making calculation for 1970-5-25
# making calculation for 1970-5-26
# making calculation for 1970-5-27
# making calculation for 1970-5-28
# making calculation for 1970-5-29
# making calculation for 1970-5-30
# making calculation for 1970-5-31
# making calculation for 1970-6-1
# making calculation for 1970-6-2
# making calculation for 1970-6-3
# making calculation for 1970-6-4
# making calculation for 1970-6-5
# making calculation for 1970-6-6
# making calculation for 1970-6-7
# making calculation for 1970-6-8
# making calculation for 1970-6-9
# making calculation for 1970-6-10
# making calculation for 1970-6-11
# making calculation for 1970-6-12
# making calculation for 1970-6-13
# making calculation for 1970-6-14
# making calculation for 1970-6-15
# making calculation for 1970-6-16
# making calculation for 1970-6-17
# making calculation for 1970-6-18
# making calculation for 1970-6-19
# making calculation for 1970-6-20
# making calculation for 1970-6-21
# making calculation for 1970-6-22
# making calculation for 1970-6-23
# making calculation for 1970-6-24
# making calculation for 1970-6-25
# making calculation for 1970-6-26
# making calculation for 1970-6-27
# making calculation for 1970-6-28
# making calculation for 1970-6-29
# making calculation for 1970-6-30
# making calculation for 1970-7-1
# making calculation for 1970-7-2
# making calculation for 1970-7-3
# making calculation for 1970-7-4
# making calculation for 1970-7-5
# making calculation for 1970-7-6
# making calculation for 1970-7-7
# making calculation for 1970-7-8
# making calculation for 1970-7-9
# making calculation for 1970-7-10
# making calculation for 1970-7-11
# making calculation for 1970-7-12
# making calculation for 1970-7-13
# making calculation for 1970-7-14
# making calculation for 1970-7-15
# making calculation for 1970-7-16
# making calculation for 1970-7-17
# making calculation for 1970-7-18
# making calculation for 1970-7-19
# making calculation for 1970-7-20
# making calculation for 1970-7-21
# making calculation for 1970-7-22
# making calculation for 1970-7-23
# making calculation for 1970-7-24
# making calculation for 1970-7-25
# making calculation for 1970-7-26
# making calculation for 1970-7-27
# making calculation for 1970-7-28
# making calculation for 1970-7-29
# making calculation for 1970-7-30
# making calculation for 1970-7-31
# making calculation for 1970-8-1
# making calculation for 1970-8-2
# making calculation for 1970-8-3
# making calculation for 1970-8-4
# making calculation for 1970-8-5
# making calculation for 1970-8-6
# making calculation for 1970-8-7
# making calculation for 1970-8-8
# making calculation for 1970-8-9
# making calculation for 1970-8-10
# making calculation for 1970-8-11
# making calculation for 1970-8-12
# making calculation for 1970-8-13
# making calculation for 1970-8-14
# making calculation for 1970-8-15
# making calculation for 1970-8-16
# making calculation for 1970-8-17
# making calculation for 1970-8-18
# making calculation for 1970-8-19
# making calculation for 1970-8-20
# making calculation for 1970-8-21
# making calculation for 1970-8-22
# making calculation for 1970-8-23
# making calculation for 1970-8-24
# making calculation for 1970-8-25
# making calculation for 1970-8-26
# making calculation for 1970-8-27
# making calculation for 1970-8-28
# making calculation for 1970-8-29
# making calculation for 1970-8-30
# making calculation for 1970-8-31
# making calculation for 1970-9-1
# making calculation for 1970-9-2
# making calculation for 1970-9-3
# making calculation for 1970-9-4
# making calculation for 1970-9-5
# making calculation for 1970-9-6
# making calculation for 1970-9-7
# making calculation for 1970-9-8
# making calculation for 1970-9-9
# making calculation for 1970-9-10
# making calculation for 1970-9-11
# making calculation for 1970-9-12
# making calculation for 1970-9-13
# making calculation for 1970-9-14
# making calculation for 1970-9-15
# making calculation for 1970-9-16
# making calculation for 1970-9-17
# making calculation for 1970-9-18
# making calculation for 1970-9-19
# making calculation for 1970-9-20
# making calculation for 1970-9-21
# making calculation for 1970-9-22
# making calculation for 1970-9-23
# making calculation for 1970-9-24
# making calculation for 1970-9-25
# making calculation for 1970-9-26
# making calculation for 1970-9-27
# making calculation for 1970-9-28
# making calculation for 1970-9-29
# making calculation for 1970-9-30
# making calculation for 1970-10-1
# making calculation for 1970-10-2
# making calculation for 1970-10-3
# making calculation for 1970-10-4
# making calculation for 1970-10-5
# making calculation for 1970-10-6
# making calculation for 1970-10-7
# making calculation for 1970-10-8
# making calculation for 1970-10-9
# making calculation for 1970-10-10
# making calculation for 1970-10-11
# making calculation for 1970-10-12
# making calculation for 1970-10-13
# making calculation for 1970-10-14
# making calculation for 1970-10-15
# making calculation for 1970-10-16
# making calculation for 1970-10-17
# making calculation for 1970-10-18
# making calculation for 1970-10-19
# making calculation for 1970-10-20
# making calculation for 1970-10-21
# making calculation for 1970-10-22
# making calculation for 1970-10-23
# making calculation for 1970-10-24
# making calculation for 1970-10-25
# making calculation for 1970-10-26
# making calculation for 1970-10-27
# making calculation for 1970-10-28
# making calculation for 1970-10-29
# making calculation for 1970-10-30
# making calculation for 1970-10-31
# making calculation for 1970-11-1
# making calculation for 1970-11-2
# making calculation for 1970-11-3
# making calculation for 1970-11-4
# making calculation for 1970-11-5
# making calculation for 1970-11-6
# making calculation for 1970-11-7
# making calculation for 1970-11-8
# making calculation for 1970-11-9
# making calculation for 1970-11-10
# making calculation for 1970-11-11
# making calculation for 1970-11-12
# making calculation for 1970-11-13
# making calculation for 1970-11-14
# making calculation for 1970-11-15
# making calculation for 1970-11-16
# making calculation for 1970-11-17
# making calculation for 1970-11-18
# making calculation for 1970-11-19
# making calculation for 1970-11-20
# making calculation for 1970-11-21
# making calculation for 1970-11-22
# making calculation for 1970-11-23
# making calculation for 1970-11-24
# making calculation for 1970-11-25
# making calculation for 1970-11-26
# making calculation for 1970-11-27
# making calculation for 1970-11-28
# making calculation for 1970-11-29
# making calculation for 1970-11-30
# making calculation for 1970-12-1
# making calculation for 1970-12-2
# making calculation for 1970-12-3
# making calculation for 1970-12-4
# making calculation for 1970-12-5
# making calculation for 1970-12-6
# making calculation for 1970-12-7
# making calculation for 1970-12-8
# making calculation for 1970-12-9
# making calculation for 1970-12-10
# making calculation for 1970-12-11
# making calculation for 1970-12-12
# making calculation for 1970-12-13
# making calculation for 1970-12-14
# making calculation for 1970-12-15
# making calculation for 1970-12-16
# making calculation for 1970-12-17
# making calculation for 1970-12-18
# making calculation for 1970-12-19
# making calculation for 1970-12-20
# making calculation for 1970-12-21
# making calculation for 1970-12-22
# making calculation for 1970-12-23
# making calculation for 1970-12-24
# making calculation for 1970-12-25
# making calculation for 1970-12-26
# making calculation for 1970-12-27
# making calculation for 1970-12-28
# making calculation for 1970-12-29
# making calculation for 1970-12-30
# making calculation for 1970-12-31

# %% [markdown]
# #### Convert the output dictionaries to dataframes

# %%
mycell_exp.convert_dict_to_df()
py_exp_df = mycell_exp.output_df.copy()
py_exp_df.loc[:,'date'] = pd.to_datetime(py_exp_df['date'])

# %%
mycell_tab.convert_dict_to_df()
py_tab_df = mycell_tab.output_df.copy()
py_tab_df.loc[:,'date'] = pd.to_datetime(py_tab_df['date'])

# %%
mycell_eqns.convert_dict_to_df()
py_eqns_df = mycell_eqns.output_df.copy()
py_eqns_df.loc[:,'date'] = pd.to_datetime(py_eqns_df['date'])

# %% [markdown]
# #### Merge the swb and python model outputs into a single dataframe

# %%
df = pd.merge(left=py_exp_df, right=py_tab_df, on='date', suffixes=('_e','_t'))
df = pd.merge(left=df, right=py_eqns_df, on='date', suffixes=(None,'_q'))
df = pd.merge(left=df, right=swb_df, on='date', suffixes=(None, '_s'))
display(df.columns.to_list())
# Out:
# ['date',
#  'previous_soil_storage_e',
#  'soil_storage_e',
#  'rainfall_e',
#  'snow_storage_e',
#  'snowfall_e',
#  'snowmelt_e',
#  'pet_e',
#  'p_minus_pet_e',
#  'aet_e',
#  'net_infiltration_e',
#  'apwl_e',
#  'previous_soil_storage_t',
#  'soil_storage_t',
#  'rainfall_t',
#  'snow_storage_t',
#  'snowfall_t',
#  'snowmelt_t',
#  'pet_t',
#  'p_minus_pet_t',
#  'aet_t',
#  'net_infiltration_t',
#  'apwl_t',
#  'previous_soil_storage',
#  'soil_storage',
#  'rainfall',
#  'snow_storage',
#  'snowfall',
#  'snowmelt',
#  'pet',
#  'p_minus_pet',
#  'aet',
#  'net_infiltration',
#  'apwl',
#  'month',
#  'day',
#  'year',
#  'landuse_code',
#  'landuse_index',
#  'soil_group',
#  'num_upslope_connections',
#  'sum_upslope_cells',
#  'solution_order',
#  'cell_index',
#  'target_index',
#  'awc',
#  'latitude',
#  'reference_ET0',
#  'actual_ET',
#  'curve_num_adj',
#  'gross_precip',
#  'inflow',
#  'runon',
#  'runoff',
#  'outflow',
#  'infiltration',
#  'snowfall_s',
#  'potential_snowmelt',
#  'snowmelt_s',
#  'interception',
#  'rainfall_s',
#  'net_rainfall',
#  'monthly_gross_precip',
#  'monthly_runoff',
#  'interception_storage',
#  'tmax',
#  'tmin',
#  'tmean',
#  'snow_storage_s',
#  'soil_storage_s',
#  'soil_storage_max',
#  'evaporable_water_storage',
#  'evaporable_water_deficit',
#  'delta_soil_storage',
#  'soil_moisture_deficit',
#  'surface_storage',
#  'surface_storage_excess',
#  'surface_storage_max',
#  'net_infiltration_s',
#  'rejected_net_infiltration',
#  'fog',
#  'irrigation',
#  'gdd',
#  'runoff_outside',
#  'pervious_fraction',
#  'storm_drain_capture',
#  'canopy_cover_fraction',
#  'crop_coefficient_kcb',
#  'cfgi',
#  'rooting_depth_max',
#  'current_rooting_depth',
#  'current_plant_height',
#  'actual_et_soil',
#  'readily_available_water',
#  'total_available_water',
#  'plant_stress_coef_ks',
#  'evap_reduction_coef_kr',
#  'surf_evap_coef_ke',
#  'fraction_exposed_and_wetted_soil',
#  'actual_et_impervious',
#  'actual_et_interception',
#  'adjusted_depletion_fraction_p',
#  'crop_etc',
#  'bare_soil_evap',
#  'direct_net_infiltration',
#  'direct_soil_moisture',
#  'inflowbuf1',
#  'inflowbuf2',
#  'inflowbuf3',
#  'inflowbuf4',
#  'inflowbuf5',
#  'inflowbuf_sum',
#  'tminf',
#  'tmaxf',
#  'tmeanf']

# %%
# estimate 'P minus PET' for swb
df['p_minus_pet'] = (df['snowmelt'] + df['rainfall'] - df['crop_etc']) * 25.4

# %% [markdown]
# ## Test comparisons

# %%
my_subset = df[(df['date'] > "1967-01-01") & (df['date'] < "1968-12-31")]
#my_subset[['date','tmin','tmax','tmean','tminf','tmaxf','tmeanf','gross_precip','soil_storage_s','soil_storage_p',
#           'infiltration', 'p_minus_pet_s','p_minus_pet',
#           'reference_ET0','pet','actual_ET','aet']]
df = my_subset

# %% [markdown]
# ### SNOWFALL

# %% [markdown]
# SWB2 uses the same empirical relations as were used in Dripps (2003) and Dripps and Bradbury (2007) to partition gross precipitation into 'rainfall' and 'snowfall'.
#
#
# $$
# snow: T_{mean} - \frac{1}{3}(T_{max} - T_{min}) \leq 32
# $$
# $$
# rain: T_{mean} - \frac{1}{3}(T_{max} - T_{min}) > 32
# $$
#
# where:
#
# $T_{mean}$ is the mean daily air temperature, in degrees Fahrenheit,
#
# $T_{max}$ is the maximum daily air temperature, in degrees Fahrenheit,
#
# $T_{mean}$ is the minimum daily air temperature, in degrees Fahrenheit.

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 8),sharex=False)
ax.plot(df['date'], df['snowfall'], marker='.', linestyle=' ', color='blue', markersize=4, label='SWB snowfall')
ax.plot(df['date'], df['snowfall_e'], marker=' ', linestyle='-', 
        color='black', linewidth=0.75, label='Python model snowfall')
ax.set_ylabel('snowfall, in millimeters')
ax.set_title('Snowfall comparison: SWB code to Python implementation')
ax.legend()

# %% [markdown]
# ### SNOWMELT
#
# SWB2 uses the same empirical relations as were used in Dripps (2003) and Dripps and Bradbury (2007) to estimate the potential snowmelt from accumulated snowpack on a given day. Actual snowmelt is limited by the amount of moisture stored in the snow storage reservoir.
#
#
# $$
# potential\, snowmelt = 1.5 \cdot (T_{max}), \, T_{max} > 0
# $$
#
# where:
#
# $potential\, snowmelt$ is in millimeters, and
#
# $T_{max}$ is the maximum daily air temperature, in degrees Celsius.

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 8),sharex=False)
ax.plot(df['date'], df['snowmelt'], marker='.', linestyle=' ', color='red', markersize=4, label='SWB snowmelt')
ax.plot(df['date'], df['snowmelt_e'], marker=' ', linestyle='-', 
        color='black', linewidth=0.5, label='Python model snowmelt')
ax.set_ylabel('snowmelt, in millimeters')
ax.set_title('Snowmelt comparison: SWB code to Python implementation')
ax.legend()

# %% [markdown]
# ### SNOW STORAGE
#
# Snow storage evolves over the course of a run, with the snowfall and snowmelt calculated as noted above. If the snowfall and snowmelt components are consistent between the SWB code and the Python code, the snow storage evolution over time should be consistent as well.

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 8),sharex=False)
ax.plot(df['date'], df['snow_storage'], marker='.', linestyle=' ', color='purple', markersize=4, label='SWB snow storage')
ax.plot(df['date'], df['snow_storage_e'], marker=' ', linestyle='-', 
        color='black', linewidth=0.75, label='Python model snow storage')
ax.set_ylabel('snow storage, in millimeters')
ax.set_title('Snow comparison: SWB code to Python implementation')
ax.legend()

# %% [markdown]
# ### SOIL STORAGE / SOIL-MOISTURE RETENTION
#
# The first versions of the SWB code included extensive routines to read in and interpolate the tables of soil-moisture-retention data included in the appendixes of Thornthwaite and Mather (1957). Making daily calculations with the Thornthwaite-Mather tables involves consulting the soil-moisture retention tables for each days' worth of calculations. When precipitation is less than the potential or reference ET, the tables are consulted to first provide an updated value for the accumulated potential water loss, and then to calculate an updated soil moisture value. After working with the tables for some time, however, it became clear that the values are simply tabulated values calculated from an exponential relation relating the current days' soil moisture to the previous days' soil moisture (Alley, 1984):
#
# $$
# S_i = S_{i-1} \,e^\frac{-(PE_i - P_i)}{\phi}
# $$
#
# where:
#
# $S_i$ is the soil moisture on day $i$, in millimeters
#
# $S_{i-1}$ is the soil moisture on day $i-1$, in millimeters
#
# $PE$ is the potential evapotranspiration, in millimeters
#
# $P$ is the daily precipitation amount, in millimeters, and
#
# $\phi$ is the size of the soil moisture reservoir, in millimeters.
#
# Note in the figure below (top plot) that using the table values directly results in some minor departure from the calculations made with the exponential or fitted equation versions. This is likely because the tabular values are all truncated to 1mm of resolution with respect to the current values of moisture retained in the soil. There is a bit of roundoff error involved when using the tabular values directly. The issue with roundoff is lessened when equations fitted to the tabular values are used rather than the table values directly (bottom plot).

# %%
fig = plt.figure(figsize=(14, 16))

ax = fig.add_subplot(2,1,1)
ax.plot(df['date'], df['soil_storage'], marker='.', linestyle=' ', color='green', markersize=4, label='SWB')
ax.plot(df['date'], df['soil_storage_t'], marker='.', linestyle='-', color='darkgray', markersize=3, label='Python model (table)')
ax.plot(df['date'], df['soil_storage_e'], marker=' ', linestyle='-', 
        color='blue', linewidth=0.5, label='Python model (exp)')
ax.set_ylabel('Soil moisture storage, millimeters')
ax.legend()

ax = fig.add_subplot(2,1,2)
ax.plot(df['date'], df['soil_storage'], marker='.', linestyle=' ', color='green', markersize=4, label='SWB')
ax.plot(df['date'], df['soil_storage'], marker='.', linestyle='-', color='darkgray', markersize=3, label='Python model (eqns)')
ax.plot(df['date'], df['soil_storage_e'], marker=' ', linestyle='-', 
        color='blue', linewidth=0.5, label='Python model (exp)')
ax.set_ylabel('Soil moisture storage, millimeters')
ax.legend()

# %% [markdown]
# ### REFERENCE EVAPOTRANSPIRATION
#
# This test case makes use of the Hargreaves-Samani method for estimating reference evapotranspiration from only minumum and maximum daily air temperatures. There is a cascade of calculations that go into calculating reference ET using Hargreaves and Samani. First, the code makes a number of calculations relating to the potential amount of solar radiation, including the relative earth-sun distance, solar declination, and sunset angle given the current day of the year within the simulation. The difference between $T_{max}$ and $T_{min}$ is used as a proxy for the amount of potential solar radiation that reaches the land surface, and directly influences the total reference evapotranspiration calculated on a particular day.

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 8),sharex=False)
ax.plot(df['date'], df['reference_ET0'], marker='.', linestyle=' ', color='cyan', markersize=4, label='SWB reference ET0')
ax.plot(df['date'], df['pet_e'], marker=' ', linestyle='-', 
        color='black', linewidth=0.75, label='Python model reference ET0')
ax.legend()

# %% [markdown]
# ### ACTUAL EVAPOTRANSPIRATION

# %%
fig = plt.figure(figsize=(16, 14))
ax = fig.add_subplot(2,1,1)
ax.plot(df['date'], df['actual_ET'], marker='.', linestyle=' ', color='green', markersize=6, label='SWB actual ET')
ax.plot(df['date'], df['aet_t'], marker='.', linestyle='-', color='darkgray', markersize=3, label='Python model (table) actual et')
ax.plot(df['date'], df['aet_e'], marker=' ', linestyle='-', 
        color='lightgreen', linewidth=0.5, label='Python model (exp) actual et')
ax.set_ylabel('Actual evapotranspiration, millimeters')
ax.legend()

# %% [markdown]
# ### NET INFILTRATION

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 8),sharex=False)
ax.plot(df['date'], df['net_infiltration'], marker='.', linestyle=' ', color='orange', markersize=4, label='SWB net infiltration')
ax.plot(df['date'], df['net_infiltration_t'], marker=' ', linestyle='-', 
        color='black', linewidth=0.75, label='Python model net infiltration (table)')
ax.legend()
